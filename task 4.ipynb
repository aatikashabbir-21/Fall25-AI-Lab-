# %%
text = input("Enter a sentence: ")

result = ""

for ch in text:
    if ch.isalnum() or ch == " ":
        result += ch

print("Original String:", text)
print("Cleaned String:", result)
# Out:
# Original String: "hi , what's up ?
# Cleaned String: hi  whats up

# %%
sentence = input("Enter a sentence: ")

word_list = []
word = ""

for char in sentence:
    if char != " ":
        word += char
    else:
        if word:
            word_list.append(word)
            word = ""
if word:
    word_list.append(word)

for i in range(len(word_list)):
    for j in range(len(word_list) - i - 1):
        x, y = word_list[j], word_list[j + 1]
        index = 0
        while index < len(x) and index < len(y) and x[index] == y[index]:
            index += 1
        if index < len(x) and (index == len(y) or ord(x[index]) > ord(y[index])):
            word_list[j], word_list[j + 1] = word_list[j + 1], word_list[j]

print("Words arranged by ASCII order:")
for w in word_list:
    print(w, end=" ")
# Out:
# Words arranged by ASCII order:
# am good i
